# %% [markdown]
# # 05 - Spatial Analysis
#
# **Owner:** Member 3
#
# ## Purpose
# Starter notebook for hotspot and origin-destination exploratory analysis.
#
# ## Expected inputs
# - Spatially relevant processed datasets from `data/processed/`
#
# ## Expected outputs
# - Hotspot / OD analysis notes
# - Placeholder spatial figures
#
# ## TODO checklist
# - [ ] Confirm local data availability (relative paths only)
# - [ ] Add exploratory notes/assumptions
# - [ ] Add task-specific preprocessing or feature steps
# - [ ] Add evaluation summary placeholders
