# %% [markdown]
# # 04 - Demand Forecasting
#
# **Owner:** Member 3
#
# ## Purpose
# Starter notebook for temporal demand forecasting tasks.
#
# ## Expected inputs
# - Time-aggregated processed data from `data/processed/`
#
# ## Expected outputs
# - Forecasting experiment notes
# - Placeholder plots to be saved in `figures/`
#
# ## TODO checklist
# - [ ] Confirm local data availability (relative paths only)
# - [ ] Add exploratory notes/assumptions
# - [ ] Add task-specific preprocessing or feature steps
# - [ ] Add evaluation summary placeholders
