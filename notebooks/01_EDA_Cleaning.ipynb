# %% [markdown]
# # 01 - EDA & Cleaning
#
# **Owner:** Member 1
#
# ## Purpose
# Initial exploratory data analysis, quality checks, and baseline cleaning plan.
#
# ## Expected inputs
# - Raw competition files from `data/raw/`
#
# ## Expected outputs
# - Cleaned intermediate datasets in `data/processed/`
# - Documented feature assumptions shared with the team
#
# ## TODO checklist
# - [ ] Confirm local data availability (relative paths only)
# - [ ] Add exploratory notes/assumptions
# - [ ] Add task-specific preprocessing or feature steps
# - [ ] Add evaluation summary placeholders
